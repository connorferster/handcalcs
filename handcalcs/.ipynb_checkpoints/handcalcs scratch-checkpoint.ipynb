# %%
import handcalcs as hc
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-10f8a1af6fbf> in <module>
# ----> 1 import handcalcs as hc
#
# ModuleNotFoundError: No module named 'handcalcs'
